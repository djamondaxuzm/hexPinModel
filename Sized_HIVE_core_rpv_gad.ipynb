# %%
# %matplotlib inline 
import numpy as np 
import os 
import math 
os.environ["PATH"] = "/storage/work/ugh5000/.conda/envs/openmc/bin:" + os.environ["PATH"] 
import openmc 
os.environ["OPENMC_CROSS_SECTIONS"] = "/storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/cross_sections.xml"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"

## Defining materials


# This "fuel" is the classic UO2 and I added gadolinium as a burnable poison just to experiment (very sensitive to gad concentration). 
# I doubt that this is right so it will have to be revised. It should be a mix of UO2 and Gd2O3
fuel = openmc.Material(name='uo2_gad') 
fuel.add_nuclide('U235', 0.18) 
fuel.add_nuclide('U238', 0.82)
fuel.add_element('Gd', 0.00085)
fuel.add_nuclide('O16', 5) 
fuel.set_density('g/cm3', 11.5) 

cladding = openmc.Material(name='zircaloy4') 
cladding.add_element('Zr',0.98) 
cladding.add_element('Sn',0.015) 
cladding.add_element('Fe',0.002) 
cladding.add_element('Cr',0.001) 
cladding.add_element('O',0.001) 
cladding.add_element('Hf', 0.001) 
cladding.set_density('g/cm3', 6.34) 

water = openmc.Material(name='h2o') 
water.add_nuclide('H1', 2.0) 
water.add_nuclide('O16', 1.0) 
water.set_density('g/cm3', 1.0) 
water.add_s_alpha_beta('c_H_in_H2O')

ctrl_rod = openmc.Material(name='bc4')
ctrl_rod.add_nuclide('B10', 0.7)
ctrl_rod.add_nuclide('B11', 0.3)
ctrl_rod.add_nuclide('C12', 4)
ctrl_rod.set_density('g/cm3', 2.5)

rpv = openmc.Material(name='stainless_steel')   #Not really following any stablished "named" materials, just went with an approximation
rpv.add_element('Fe', 0.7)
rpv.add_element('Cr', 0.2)
rpv.add_element('Ni', 0.08)
rpv.add_element('Mn', 0.01)
rpv.add_element('C', 0.01)
rpv.set_density('g/cm3', 7.6)

mats = openmc.Materials([fuel, cladding, water, ctrl_rod, rpv]) 
mats.export_to_xml() 



## Defining geometry


# First defining dimensions and limiting surfaces for fuel, clad, and (when we had them) control rods
# Specify boundary conditions only to the exterior surfaces
# Changed the radius of the pellet to be more realistic (1 whole cm was a lot)

H_core = 225
R_core = 150
cyl_uo2 = openmc.ZCylinder(r=0.6)
cyl_clad = openmc.ZCylinder(r=0.62)
cyl_ctrl = openmc.ZCylinder(r=0.62)
cyl_rpv_i = openmc.ZCylinder(r=R_core-10)
cyl_rpv_o = openmc.ZCylinder(r=R_core, boundary_type='vacuum')
z_max = openmc.ZPlane(z0=H_core, boundary_type='vacuum')
z_min = openmc.ZPlane(z0=-H_core, boundary_type='vacuum')

# regions
uo2_region = -cyl_uo2 & -z_max & +z_min
clad_region = +cyl_uo2 & -cyl_clad & -z_max & +z_min
water_region = +cyl_clad & -z_max & +z_min
ctrl_region = -cyl_ctrl & -z_max & +z_min
water_ctrl_region = +cyl_ctrl & -z_max & +z_min
rpv_region = +cyl_rpv_i & -cyl_rpv_o & -z_max & +z_min


# cells
uo2_cell = openmc.Cell(name='fuel')
uo2_cell.region = uo2_region
uo2_cell.fill = fuel

clad_cell = openmc.Cell(name='cladding')
clad_cell.region = clad_region
clad_cell.fill = cladding

ctrl_cell = openmc.Cell(name='rod')
ctrl_cell.region = ctrl_region
ctrl_cell.fill = ctrl_rod

water_cell = openmc.Cell(name='water')
water_cell.region = water_region
water_cell.fill = water

water_cell_ctrl = openmc.Cell(name='water_ctrl')        # This might be unnecessary, essentially the same as the water cell
water_cell_ctrl.region = water_ctrl_region
water_cell_ctrl.fill = water

rpv_cell = openmc.Cell(name='vessel')
rpv_cell.region = rpv_region
rpv_cell.fill = rpv

# universes, the outer universe i see it as a safety net so that everything is covered

fuel_universe = openmc.Universe(cells=[uo2_cell, clad_cell, water_cell])
ctrl_rod_universe = openmc.Universe(cells=[ctrl_cell, water_cell_ctrl])
outer_universe = openmc.Universe(cells=[openmc.Cell(fill=water)])


lat = openmc.HexLattice()    # this is the lattice of the fuel pins arranged into 3 rings to form the assembly
lat.center = (0., 0.)
lat.pitch = (4.6,)           # i picked this number just to make it fit, no calculations. 
# Changing this number affects k-eff a lot. Could make it smaller and even fit one more assembly ring
lat.outer = outer_universe

outer_ring = [fuel_universe] * 12
middle_ring = [fuel_universe] * 6
inner_ring = [fuel_universe]         # this used to be ctrl_rod_universe, but since we need burnable poisons it needs to be uncontrolled
lat.universes = [outer_ring, middle_ring, inner_ring] # this completely defines the lattice structure


# this defines the fuel assembly cell so that it can be stacked
a = 2.75 * lat.pitch[0]  # formula
outer_boundary = openmc.model.hexagonal_prism(edge_length=a, orientation='y')
main_cell = openmc.Cell(fill=lat, region=outer_boundary & -z_max & +z_min)

assembly_univ = openmc.Universe(cells=[main_cell]) #just "converting" the cell into a universe so that it can be merged

core_lat = openmc.HexLattice()
core_lat.center = (0.,0.)
core_lat.pitch = (np.sqrt(3)*a-0.8,)  # the sqrt3*a is the formula, then manually adjusting it so that it looks homogeneous
core_lat.outer = outer_universe # used the same outer as when defining the assemblies, it does not matter
core_lat.orientation = 'x' # these orientations are either x or y. I just change them until they agree lol

ring_1 = [assembly_univ]
ring_2 = [assembly_univ] * 6
ring_3 = [assembly_univ] * 12
ring_4 = [assembly_univ] * 18
ring_5 = [assembly_univ] * 24
ring_6 = [assembly_univ] * 30
ring_7 = [assembly_univ] * 36
core_lat.universes = [ring_7, ring_6, ring_5, ring_4, ring_3, ring_2, ring_1]

# only the "water" of the core, no pressure vessel
whole_core_cell = openmc.Cell(fill=core_lat, region=-cyl_rpv_i & -z_max & +z_min)

geom = openmc.Geometry([whole_core_cell, rpv_cell]) #pressure vessel added here
geom.export_to_xml()

p = openmc.Plot() 
p.basis = 'xy'       
p.origin = (0, 0, 0) 
p.width = (305, 305)   
p.color_by = 'material'
p.colors = {water: 'blue',fuel: 'black',cladding: 'red',ctrl_rod: 'gray', rpv: 'purple'}

p.path_to_geometry = geom.export_to_xml()

p.to_ipython_image()
# Out:
# /storage/work/ugh5000/.conda/envs/openmc-env/lib/python3.11/site-packages/openmc/model/funcs.py:124: FutureWarning: The hexagonal_prism(...) function has been replaced by the HexagonalPrism(...) class. Future versions of OpenMC will not accept hexagonal_prism.
#   warn("The hexagonal_prism(...) function has been replaced by the "

# %%
settings = openmc.Settings()
settings.batches = 100
settings.inactive = 10
settings.particles = 1000
settings.run_mode = 'eigenvalue'
settings.export_to_xml()

# %%
# failed trial run 

r_grid_num = np.linspace(0,R_core,15)
z_grid_num = np.linspace(-H_core,H_core, 50)
phi_grid_num = np.array([0, 2*np.pi])

mesh = openmc.CylindricalMesh(
    r_grid = r_grid_num,
    z_grid = z_grid_num,
    phi_grid = phi_grid_num,
    origin = (0.0,0.0,0.0)
)

mesh_filter = openmc.MeshFilter(mesh)

flux_tally = openmc.Tally(name='raw_flux')
flux_tally.filter = [mesh_filter]
flux_tally.scores = ['flux']

tallies = openmc.Tallies([flux_tally])
#tallies.export_to_xml()


openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-11-27 16:35:32
#   OpenMP Threads | 4
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U235 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/U235.h5
#  Reading U238 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/U238.h5
#  Reading Gd152 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Gd152.h5
#  Reading Gd154 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Gd154.h5
#  Reading Gd155 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Gd155.h5
#  Reading Gd156 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Gd156.h5
#  Reading Gd157 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Gd157.h5
#  Reading Gd158 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Gd158.h5
#  Reading Gd160 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Gd160.h5
#  Reading O16 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/O16.h5
#  Reading Zr90 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Zr90.h5
#  Reading Zr91 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Zr91.h5
#  Reading Zr92 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Zr92.h5
#  Reading Zr94 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Zr94.h5
#  Reading Zr96 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Zr96.h5
#  WARNING: Negative value(s) found on probability table for nuclide Zr96 at 294K
#  Reading Sn112 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn112.h5
#  Reading Sn114 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn114.h5
#  Reading Sn115 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn115.h5
#  Reading Sn116 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn116.h5
#  Reading Sn117 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn117.h5
#  Reading Sn118 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn118.h5
#  Reading Sn119 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn119.h5
#  Reading Sn120 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn120.h5
#  Reading Sn122 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn122.h5
#  Reading Sn124 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Sn124.h5
#  Reading Fe54 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Fe54.h5
#  Reading Fe56 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Fe56.h5
#  Reading Fe57 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Fe57.h5
#  Reading Fe58 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Fe58.h5
#  Reading Cr50 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Cr50.h5
#  Reading Cr52 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Cr52.h5
#  Reading Cr53 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Cr53.h5
#  Reading Cr54 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Cr54.h5
#  Reading O17 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/O17.h5
#  Reading O18 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/O18.h5
#  Reading Hf174 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Hf174.h5
#  Reading Hf176 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Hf176.h5
#  Reading Hf177 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Hf177.h5
#  Reading Hf178 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Hf178.h5
#  Reading Hf179 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Hf179.h5
#  Reading Hf180 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Hf180.h5
#  Reading H1 from /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/H1.h5
#  Reading B10 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/B10.h5
#  Reading B11 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/B11.h5
#  Reading C12 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/C12.h5
#  Reading Ni58 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Ni58.h5
#  Reading Ni60 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Ni60.h5
#  Reading Ni61 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Ni61.h5
#  Reading Ni62 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Ni62.h5
#  Reading Ni64 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Ni64.h5
#  Reading Mn55 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/Mn55.h5
#  Reading C13 from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/C13.h5
#  Reading c_H_in_H2O from
#  /storage/work/ugh5000/openmc_xs/endfb-viii.0-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Gd152
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.09406
#         2/1    1.02440
#         3/1    0.93220
#         4/1    1.00641
#         5/1    1.06141
#         6/1    0.96934
#         7/1    1.01109
#         8/1    1.04808
#         9/1    0.98124
#        10/1    1.01985
#        11/1    1.00243
#        12/1    0.99152    0.99698 +/- 0.00546
#        13/1    1.02662    1.00686 +/- 0.01037
#        14/1    1.00484    1.00635 +/- 0.00735
#        15/1    1.02763    1.01061 +/- 0.00711
#        16/1    1.04955    1.01710 +/- 0.00871
#        17/1    1.01913    1.01739 +/- 0.00736
#        18/1    1.07534    1.02463 +/- 0.00965
#        19/1    0.98858    1.02063 +/- 0.00941
#        20/1    0.94811    1.01337 +/- 0.01111
#        21/1    0.99533    1.01173 +/- 0.01018
#        22/1    0.97901    1.00901 +/- 0.00969
#        23/1    1.03966    1.01137 +/- 0.00922
#        24/1    1.03657    1.01317 +/- 0.00872
#        25/1    1.01091    1.01302 +/- 0.00812
#        26/1    1.03369    1.01431 +/- 0.00770
#        27/1    0.98919    1.01283 +/- 0.00739
#        28/1    1.02250    1.01337 +/- 0.00698
#        29/1    1.08179    1.01697 +/- 0.00752
#        30/1    0.97411    1.01483 +/- 0.00745
#        31/1    0.90764    1.00972 +/- 0.00874
#        32/1    0.98565    1.00863 +/- 0.00840
#        33/1    0.97339    1.00709 +/- 0.00817
#        34/1    0.99436    1.00656 +/- 0.00784
#        35/1    1.02530    1.00731 +/- 0.00756
#        36/1    1.01946    1.00778 +/- 0.00728
#        37/1    1.02957    1.00859 +/- 0.00705
#        38/1    0.98030    1.00758 +/- 0.00687
#        39/1    1.10566    1.01096 +/- 0.00744
#        40/1    1.02014    1.01127 +/- 0.00719
#        41/1    1.03142    1.01192 +/- 0.00699
#        42/1    0.99924    1.01152 +/- 0.00678
#        43/1    1.01063    1.01149 +/- 0.00657
#        44/1    1.01126    1.01149 +/- 0.00637
#        45/1    1.03956    1.01229 +/- 0.00624
#        46/1    0.95106    1.01059 +/- 0.00630
#        47/1    1.01004    1.01057 +/- 0.00613
#        48/1    1.03318    1.01117 +/- 0.00599
#        49/1    0.99314    1.01071 +/- 0.00585
#        50/1    0.95212    1.00924 +/- 0.00589
#        51/1    0.92355    1.00715 +/- 0.00611
#        52/1    1.00952    1.00721 +/- 0.00597
#        53/1    0.95675    1.00603 +/- 0.00594
#        54/1    1.00403    1.00599 +/- 0.00581
#        55/1    1.03779    1.00670 +/- 0.00572
#        56/1    1.05554    1.00776 +/- 0.00569
#        57/1    0.98226    1.00721 +/- 0.00560
#        58/1    1.03170    1.00772 +/- 0.00550
#        59/1    1.08618    1.00933 +/- 0.00562
#        60/1    0.98795    1.00890 +/- 0.00553
#        61/1    0.92278    1.00721 +/- 0.00567
#        62/1    1.02913    1.00763 +/- 0.00558
#        63/1    1.06624    1.00874 +/- 0.00558
#        64/1    0.98956    1.00838 +/- 0.00549
#        65/1    1.06027    1.00933 +/- 0.00547
#        66/1    0.98526    1.00890 +/- 0.00539
#        67/1    0.98425    1.00846 +/- 0.00531
#        68/1    0.99853    1.00829 +/- 0.00522
#        69/1    0.99862    1.00813 +/- 0.00514
#        70/1    0.89328    1.00621 +/- 0.00540
#        71/1    1.13806    1.00838 +/- 0.00573
#        72/1    0.99190    1.00811 +/- 0.00565
#        73/1    0.89776    1.00636 +/- 0.00583
#        74/1    0.96746    1.00575 +/- 0.00577
#        75/1    0.97022    1.00520 +/- 0.00570
#        76/1    0.94497    1.00429 +/- 0.00569
#        77/1    0.94358    1.00338 +/- 0.00568
#        78/1    0.91316    1.00206 +/- 0.00575
#        79/1    0.98490    1.00181 +/- 0.00567
#        80/1    0.96241    1.00125 +/- 0.00562
#        81/1    0.95841    1.00064 +/- 0.00557
#        82/1    1.03820    1.00116 +/- 0.00552
#        83/1    0.97852    1.00085 +/- 0.00545
#        84/1    0.95700    1.00026 +/- 0.00541
#        85/1    1.05690    1.00102 +/- 0.00539
#        86/1    1.05574    1.00174 +/- 0.00537
#        87/1    0.97955    1.00145 +/- 0.00530
#        88/1    1.00307    1.00147 +/- 0.00524
#        89/1    1.01909    1.00169 +/- 0.00517
#        90/1    0.99099    1.00156 +/- 0.00511
#        91/1    1.01185    1.00169 +/- 0.00505
#        92/1    0.96877    1.00128 +/- 0.00500
#        93/1    1.01053    1.00140 +/- 0.00494
#        94/1    0.98299    1.00118 +/- 0.00489
#        95/1    1.03313    1.00155 +/- 0.00485
#        96/1    1.04937    1.00211 +/- 0.00482
#        97/1    0.92500    1.00122 +/- 0.00485
#        98/1    1.01185    1.00134 +/- 0.00479
#        99/1    0.93410    1.00059 +/- 0.00480
#       100/1    0.96153    1.00015 +/- 0.00476
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 8.1052e+00 seconds
#    Reading cross sections          = 7.4317e+00 seconds
#  Total time in simulation          = 3.8924e+00 seconds
#    Time in transport only          = 3.8236e+00 seconds
#    Time in inactive batches        = 3.5562e-01 seconds
#    Time in active batches          = 3.5368e+00 seconds
#    Time synchronizing fission bank = 7.7095e-03 seconds
#      Sampling source sites         = 6.8611e-03 seconds
#      SEND/RECV source sites        = 8.1068e-04 seconds
#    Time accumulating tallies       = 3.9246e-04 seconds
#    Time writing statepoints        = 5.0802e-02 seconds
#  Total time for finalization       = 5.7418e-03 seconds
#  Total time elapsed                = 1.2035e+01 seconds
#  Calculation Rate (inactive)       = 28120.3 particles/second
#  Calculation Rate (active)         = 25446.6 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.00274 +/- 0.00318
#  k-effective (Track-length)  = 1.00015 +/- 0.00476
#  k-effective (Absorption)    = 1.00338 +/- 0.00344
#  Combined k-effective        = 1.00285 +/- 0.00292
#  Leakage Fraction            = 0.00058 +/- 0.00010
